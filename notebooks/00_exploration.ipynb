# %% [markdown]
# # GTZAN Music Clustering - Data Exploration
#
# This notebook explores the GTZAN dataset and generated features.

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display

# Add src to path
sys.path.append('../src')

from config import Config

# Configure plots
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %matplotlib inline

# %% [markdown]
# ## Load Configuration and Metadata

# %%
config = Config()

# Load metadata
metadata_path = config.metadata_path
if os.path.exists(metadata_path):
    df = pd.read_csv(metadata_path)
    print(f"Loaded {len(df)} clips")
    display(df.head())
else:
    print(f"Metadata not found: {metadata_path}")
    print("Run: python src/preprocess.py")

# %% [markdown]
# ## Dataset Statistics

# %%
# Genre distribution
if 'df' in locals():
    print("\nGenre distribution:")
    print(df['genre'].value_counts())
    
    # Plot genre distribution
    plt.figure(figsize=(10, 5))
    df['genre'].value_counts().sort_index().plot(kind='bar')
    plt.title('Clips per Genre')
    plt.xlabel('Genre')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Summary
#
# This notebook provides an overview of the dataset. See the code for more exploration examples.
#
# Next steps:
# 1. Run baselines: `python src/baselines.py`
# 2. Train models: `python src/train.py --mode vae_mlp`
# 3. View results: Open `01_results_and_plots.ipynb`
